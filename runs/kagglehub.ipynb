# %%
import kagglehub
import os
# Download latest version
path = kagglehub.dataset_download("navoneel/brain-mri-images-for-brain-tumor-detection")

print("Path to dataset files:", path)
print(os.listdir(path))
# Out:
# Path to dataset files: /Users/zideng/.cache/kagglehub/datasets/navoneel/brain-mri-images-for-brain-tumor-detection/versions/1
# ['brain_tumor_dataset', 'no', 'yes']

# %%
Path to dataset files: /Users/zideng/.cache/kagglehub/datasets/navoneel/brain-mri-images-for-brain-tumor-detection/versions/1['brain_tumor_dataset', 'no', 'yes']

# %%
from PIL import Image

# %%
from datasets import load_dataset


# Load the dataset into Hugging Face datasets library
dataset = load_dataset("imagefolder", data_dir=f'{path}')

# Check the dataset structure
print("Dataset structure:")
print(dataset)

# Check a single example
print("First example:", dataset["train"][0])
# Out:
# Resolving data files:   0%|          | 0/506 [00:00<?, ?it/s]
# Dataset structure:
# DatasetDict({
#     train: Dataset({
#         features: ['image'],
#         num_rows: 506
#     })
# })
# First example: {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=L size=630x630 at 0x312210310>}

# %%
(dataset['train']['label']).count(0)
# Out:
# 98

# %%
print("First example:", dataset["train"][0]["label"])
# Out:
# First example: 0

# %%
# Display the image
display(dataset["train"][0]['image'])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=630x630>
